# %% [markdown]
# 1. Import openAI dependences (load with conda install openai)

# %%
#Import openAI dependences (module)
import openai
import requests
import os
from io import BytesIO
from PIL import Image

# %% [markdown]
# 2. Use the API Key from openAI page

# %%
#Add our API Key copied from openAI page
openai.api_key = "sk-proj-fVzDRkGet9LvYnJih96cT3BlbkFJX7u4wXJm3hw9NDPmGa4t" #Example -> dw-bQyr9128F49VJRNKAnST32lbkFJ2Zv4qEhWo4R0Xh6yrh15

# %% [markdown]
# 3. Make a request

# %%
#Make the context of our prompt envoirement
context = 'Eres un asistente especialista en creacion de avatares humano hiperrealistas, a partir de datos generados por el usuario como genero, edad, pais, entre otros. Tendras la capacidad de crear un prompt descriptivo para la creacion de una imagen en otro modelo de IA'

#prompt (text/user's question)
gender = input("¿Cual es tu genero? (masculino/femenino)")
age = input("¿Cual es tu edad?")
country = input("¿Cual es tu nacionalidad?")

#print(prompt)
prompt = f"Genera una imagen de avatar humano hiperrealista, donde tome como referencia el genero {gender} de {age} años de edad y una nacionalidad {country}"
# Out:
# ¿Cual es tu genero? (masculino/femenino) masculino
# ¿Cual es tu edad? 29
# ¿Cual es tu nacionalidad? argentina

# %% [markdown]
# 4. Settings

# %%
# Make the request for the image prompt
image_response = openai.Image.create(
    prompt=prompt,
    n=1,
    size="1024x1024"
)

# Get and print the generated image URL
print(image_response['data'][0]['url'])
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-VQyNQRWDgspjldCWllprBfXW/user-S4qyX2ildshTnVDpy87KApyu/img-Fe5vTdxRNxy3tK4AuhiWSJX1.png?st=2024-07-25T23%3A05%3A21Z&se=2024-07-26T01%3A05%3A21Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-07-25T17%3A43%3A25Z&ske=2024-07-26T17%3A43%3A25Z&sks=b&skv=2023-11-03&sig=2btyGjilX5GDnDI1lOJbQ2vgxH878y0FsRlM3%2B8ecds%3D

# %%
# Download the logo
response = requests.get(image_response['data'][0]['url'])

# Verify if possible to download
if response.status_code == 200:
    # Get filename
    filename = os.path.basename(image_response['data'][0]['url'])
        # Agregar la extensión ".png"
    filename += ".png"
    
    # Directory to save the image
    directory = "./generated_images/"
    
    # Make directory if not exists
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    # Complete path
    filepath = os.path.join(directory, filename)
    
    # Save the image
    with open(filepath, 'wb') as f:
        f.write(response.content)
        
    print("La imagen ha sido descargada y almacenada correctamente en:", filepath)
    img = Image.open(filepath)
    print(f"Prompt utilizado: {prompt}")
    display(img)

else:
    print("Hubo un error al descargar la imagen.")
# Out:
# La imagen ha sido descargada y almacenada correctamente en: ./generated_images/cIv0vSenRZf7Bb2yQcW6odbUA1WjtEA%3D.png
# Prompt utilizado: El prompt para la creación de una imagen de un logo minimalista basado en la frase "Revolucion de IA" podría ser el siguiente:
#
# "Logo minimalista que represente la Revolución de la Inteligencia Artificial. Debe incorporar elementos icónicos que simbolicen avance tecnológico, innovación y progreso. Utilizar una paleta de colores moderna y contrastante para resaltar la idea de transformación y cambio en el mundo digital. El diseño debe ser limpio, simple y fácilmente reconocible, transmitiendo la idea de una revolución en la inteligencia artificial."
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
